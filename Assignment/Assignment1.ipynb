# %%
# 1.Switch values of two integers
# Input: n1 = 20, n2 = 30
# Output: n1 = 30, n2 = 20
n1=20
n2=30
print("***************************************")
print(f"before swapping char1={n1},char2={n2}")
print("***************************************")
temp=n1
n1=n2
n2=temp
print(f"After swapping char1={n1},char2={n2}")
# Out:
# ***************************************
# before swapping char1=20,char2=30
# ***************************************
# After swapping char1=30,char2=20

# %%
# 2. Switch values of two strings (characters)
# Input: char1 = "hello", char2 = "java"
# Output: char1 = "java", char2 = "hello"

char1="hello"
char2="java"
print(f"Before swapping char1={char1},char2={char2}")
temp=char1
char1=char2
char2=temp
print(f"After swapping char1={char1},char2={char2}")
# Out:
# Before swapping char1=hello,char2=java
# After swapping char1=java,char2=hello

# %%
# Switch one string value with one integer value
# Input: n1 = 200, char2 = "java"
# Output: n1 = "java", char2 = 200
n1=200
char2 = "java"
print("***************************************")
print(f"before swapping n1={n1},char2={char2}")
print("***************************************")
temp=n1
n1=char2
char2=temp
print(f"After swapping n1={n1},char2={char2}")
# Out:
# ***************************************
# before swapping n1=200,char2=java
# ***************************************
# After swapping n1=java,char2=200

# %%
# 5. Update balance after deposit
# Initial balance: current_balance = 10000
# Deposit amount: deposit_balance = 5000
# Output:
# ○ Before deposit: current_balance = 10000
# ○ After deposit: current_balance = 15000

current_balance = 10000
deposit_balance = 5000
total = current_balance +deposit_balance
print(f"Before Deposite : {current_balance}")
print(f"After Deposite : {total}")
# Out:
# Before Deposite : 10000
# After Deposite : 15000

# %%
# 6. Update balance after withdrawal
# Before: balance = 12000
# Withdrawal: 3000

balance = 12000
Withdrawal=3000
total = balance - Withdrawal
print(f"Before withdrawal : {balance}")
print(f"After withdrawal : {total}")

# %%
# 7. Increase shopping cart items by 3
# Before: cart_items = 5
# After: ?

cart_items = 5
cart_items+=3
print("Before: cart_items = 5")
print(f"After Increase shopping cart items by 3 = {cart_items}")

# %%
# 8. Apply a 20% discount to a price
# Before: price = 1000
# After: ?

price = 1000
Percentage=price*20/100
print(f"Before: price = 1000")
print(f"After Apply a 20% discount to a price = {Percentage}")
# Out:
# Before: price = 1000
# After Apply a 20% discount to a price = 200.0

# %%
# 9. Calculate student percentage
# Input: obtain_marks = 430, out_of = 500
# Output: Percentage = ?

obtain_marks = 430
out_of = 500
Percentage=obtain_marks*100/out_of
print(f"student percentage = {Percentage}")
# Out:
# student percentage = 86.0

# %%
# 10.Calculate total and average of 4 subjects
# Input Example:
# ● Subject 1: 80
# ● Subject 2: 75
# ● Subject 3: 90
# ● Subject 4: 85


num1 = 80
num2 = 75 
num3 = 90
num4 = 85
sum_of_num = num1+num2+num3+num4
print(f" Total of 4 subjects = {sum_of_num}")
Average = (num1+num2+num3+num4)/4
print(f" Average of 4 subjects = {Average}")
# Out:
#  Total of 4 subjects = 330
#  Average of 4 subjects = 82.5

# %%
# 11. Calculate average of 3 numbers
# Input: num1 = 25, num2 = 35, num3 = 45
# Output: Average = ?

num1 = 25
num2 = 35 
num3 = 45
sum_of_num = num1+num2+num3
Average = (num1+num2+num3)/3
print(f"Average of number 3 numbers : {Average}")

# %%
#12.Calculate profit or loss percentage
#Input: cost_price = 500, selling_price = 600
#Output: Profit or Loss = ?
cost_price = 500
selling_price = 600
#profit = selling_price - cost_price
profit = 600 - 500
print("Profit =",profit)
#pro_percen = net_pro/cost_price*100
pro_percen = 100/500*100
print("Profit percentage",pro_percen)

# %%
# 13. Calculate simple interest
# Input: principal = 10000, rate = 5, time = 2
# Output: Simple_Interest = ?
# Given values
principal = 10000
rate = 5
time = 2
simple_interest = (principal * rate * time) / 100
print(f"Simple Interest = {simple_interest}")

# %%
# 14.Calculate compound interest
# Input: principal = 10000, rate = 5, time = 2
# Output: Compound Interest = ?

principal = 10000
rate = 5
time = 2
amount = principal * (1 + rate / 100) ** time - principal
# compound_interest = amount - principal
print(f"Compound Interest = {amount}")

# %%
# 15.Calculate tax on income
# Input: income = 500000, tax_rate = 10
# Output: Tax = ?
income = 500000
tax_rate = 10
Tax = income*tax_rate/100
print(Tax)

# %%
# 16. Calculate percentage increase or decrease
# Input: initial_value = 200, final_value = 250
# Output: Percentage Change = ?

initial_value = 200
final_value = 250

# Formula: ((Final - Initial) / Initial) * 100
percentage_change = ((final_value - initial_value) / initial_value) * 100

print(f"Percentage Change = {percentage_change}%")

# %%
# 17. Convert boolean to integer
# Input: True
# Output: ?
a=True
print(int(a))

# %%
# 18.Convert float to string
# Input: 45.67
# Output: ?
num=45.67
a=str(num)
print(str(a))
type(a)

# %%
# 19.Convert 20°C to Fahrenheit
# Input: 20°C
# Output: ?
c=float(input("Enter temperature in centigrade :"))
f=(1.8*c)+32
print("Temperature in Fahrenheight : ",f)

# %%
# 20. Convert 50°F to Celsius
# Input: 50°F
# Output: ?
f=float(input("Enter temperature in Fahrenheight :"))
c=((f-32)*5/9)
print("Temperature in centigrade : ",c)

# %%
# 21.Convert integer to binary
# Input: 25
# Output: ?
a=25
a_b=bin(a)
print(a_b)

# %%
# 22. Calculate area of a triangle
# Input: base = 10, height = 6
# Output: Area = ?
base=int(input("Enter breath : "))
height=int(input("Enter height : "))
area=(base*height)/2
print("Area of triagle : ",area)

# %%
# 22.Calculate perimeter of a square
# Input: side = 9
# Output: Perimeter = ?
# perimeter of a square = 4a
side = 9
perimeter_of_square = 4*side
print(f" perimeter of a square = {perimeter_of_square}")

# %%
# 23.Calculate diameter of a circle
# Input: radius = 14
# Output: Diameter = ?

# Diameter = 2xradius
radius = 14
diameter_of_circle = 2*radius
print(f" Diameter of a circle = {diameter_of_circle}")

# %%
# 24.Calculate volume of a cube
# Input: side = 5
# Output: Volume = ?
length=int(input("Enter length : "))
width=int(input("Enter width : "))
height=int(input("Enter height : "))
volume=length*width*height
print("Volume of Cubid is :",volume)

# %%
# 25.Calculate surface area of a cuboid
# Input: l = 4, b = 3, h = 2
# Output: Surface Area = ?

l = 4
b = 3
h = 2
surface_area = 2*(l*b + b*h + l*h)
print(f" Surface fo a area = {surface_area}")

# %%
# 26.Square of sum: (x + y)²
# Input: x = 5, y = 7
# Output: ?
x = 5
y = 7
z=(x**2+y**2)+2*x*y
print("(x+y)2 = ",z)

# %%
# 27.Simplify expression: x² - 4x + 4
# Input: x = 3
# Output: ?
x=3
y=x*2 - 4*x + 4
print(y)

# %%
# 25.Evaluate: (a + b)(a - b)
# Input: a = 6, b = 2
# Output: ?
a = 6
b = 2
c=(a + b)*(a - b)
print(c)

# %%
# 29.Sum of cubes: a³ + b³
# Input: a = 1, b = 2
# Output: ?
a = 1
b = 2

result = (a ** 3) + (b ** 3)
results = (a + b) * (a**2 - a*b + b**2)

print("a³ + b³ =", result)

print("a³ + b³ =", results)

# %%
# 30.Simplify: (x - y)²
# Input: x = 10, y = 6
# Output: ?
x=10
y=6
z=x**2+y**2-2*x*y
print(z)

# %%
# 31.Difference of cubes: x³ - y³
# Input: x = 4, y = 1
# Output: ?
x=4
y=1
res = (a - b) * (a**2 + a*b + b**2)
print(res)

# %%
# 32.If user input is:
# Name: Dev
# Age: 25
# City: Jaipur
# Hobby: Cooking
# Then Output is :
# Meet Dev, a 25-year-old enthusiast from Jaipur.
# When not busy with daily tasks, Dev loves spending time cooking.
# Life in Jaipur keeps Dev energetic and curious every single day.
# With coding as a passion, the future looks creative and inspiring for
# Dev in the Jaipur City.


Name = "Dev"
Age = 25
City = "Jaipur"
Hobby = "Cooking"

print(f"""Meet {Name}, a {Age}-year-old enthusiast from {City}.
When not busy with daily tasks, {Name} loves spending time {Hobby}.
Life in {City} keeps {Name} energetic and curious every single day.
With coding as a passion, the future looks creative and inspiring for
{Name} in the {City} City.""")

# %%
# 33.Create a Python program that asks the user for the following:
# ● Full Name
# ● Profession
# ● Favorite Quote
# ● Years of Experience
# Output format:
# ------------------------------------------------
# Name : <Full Name>
# Profession : <Profession>
# Experience : <Years of Experience> years
# Quote : "<Favorite Quote>"
# -------------------------------------------------


Full_Name = input("Enter your Name:")
Profession = input("Enter your Profession:")
Favorite_quote = input("Enter your Favorite Quote:")
Years_of_experience = input("Enter your Experience:")

print(f"Name : {Full_Name}")
print(f"Profession : {Profession}")
print(f"Favorite Quote : {Favorite_quote}")
print(f"Years of Experience : {Years_of_experience}")

# %%
# 34.Ask the user:
# ● Movie Name
# ● Viewer Name
# ● Seat Number
# ● Show Time
# Output format:
# 🎬 Movie Ticket 🎟
# ------------------------
# Movie : <Movie Name>
# Name : <Viewer Name>
# Seat No : <Seat Number>
# Time : <Show Time>
# Enjoy the show!
# ------------------------
Movie_name=input("Enter movie name :")
Viewer_name=input("Enter Viewer name :")
Seat_number=int(input("Enter Seat Number :"))
Show_time=input("Enter Show time :")

print("🎬 Movie Ticket 🎟")
print(f"Movie : {Movie_name}")
print(f"Name : {Viewer_name}")
print(f"Seat No : {Seat_number}")
print(f"Time : {Show_time}")
print("Enjoy the show!")
